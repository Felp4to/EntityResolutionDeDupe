# %%
import recordlinkage
from recordlinkage.datasets import load_febrl4
import pandas as pd

# %%
dfA, dfB = load_febrl4()

# %%
dfA
# Out:
#              given_name    surname street_number            address_1  \
# rec_id
# rec-1070-org   michaela    neumann             8       stanley street
# rec-1016-org   courtney    painter            12    pinkerton circuit
# rec-4405-org    charles      green            38  salkauskas crescent
# rec-1288-org    vanessa       parr           905       macquoid place
# rec-3585-org    mikayla   malloney            37        randwick road
# ...                 ...        ...           ...                  ...
# rec-2153-org    annabel   grierson            97   mclachlan crescent
# rec-1604-org     sienna   musolino            22      smeaton circuit
# rec-1003-org    bradley   matthews             2         jondol place
# rec-4883-org     brodee       egan            88          axon street
# rec-66-org        koula  houweling             3       mileham street
#
#                         address_2            suburb postcode state  \
# rec_id
# ...

# %%
dfB
# Out:
#                given_name    surname street_number             address_1  \
# rec_id
# rec-561-dup-0       elton        NaN             3         light setreet
# rec-2642-dup-0   mitchell      maxon            47         edkins street
# rec-608-dup-0         NaN      white            72       lambrigg street
# rec-3239-dup-0      elk i    menzies             1          lyster place
# rec-2886-dup-0        NaN  garanggar           NaN  may maxwell crescent
# ...                   ...        ...           ...                   ...
# rec-4495-dup-0     connor   belperio            15                   NaN
# rec-4211-dup-0     daniel      maspn             9   derrington crescent
# rec-3131-dup-0     samuel      crofs           613        banjine street
# rec-3815-dup-0       saah    beattih            60           kay's place
# rec-493-dup-0         NaN  blackwell           127         ferrier place
#
#                             address_2             suburb postcode state  \
# rec_id
# ...

# %%
indexer = recordlinkage.Index()
indexer.full()
pairs = indexer.index(dfA, dfB)
# Out:
# WARNING:recordlinkage:indexing - performance warning - A full index can result in large number of record pairs.

# %%
print (len(dfA), len(dfB), len(pairs))
# Out:
# 5000 5000 25000000

# %%
indexer = recordlinkage.Index()
indexer.block("given_name")
candidate_links = indexer.index(dfA, dfB)
# candidate_links = recordlinkage.index.SortedNeighbourhood(dfA, dfB)
len(candidate_links)
# Out:
# 77249

# %%
df_Disfold_Avengers = pd.read_json('./disfold_Avengers_m.json')
df_Disfold_Avengers
# Out:
#                                        id                        name  \
# 0    0ebfada7-a403-4c91-b9fc-e8133f4e9997                       Apple
# 1    d9c00dbd-4a9a-412a-a897-a21831e99592                     Danaher
# 2    2c4dd91f-3c1f-4109-8fd6-0973fa3c74fc                       Merck
# 3    2b79731e-a881-4786-bbf8-0a98695a9784                         Bhp
# 4    8f3b315b-daec-43db-ae5d-d996eb4a71fe                        Nike
# ..                                    ...                         ...
# 995  c74f71a4-a588-40cc-8591-c4f9b65d5e2a    Asahi Group Holdings Ltd
# 996  3b37bf4d-18d5-461a-97ce-1483793ede2e  Haitong Securities Co. Ltd
# 997  87d3caa6-747b-496f-bc8c-c937c806e81f              Catalent, Inc.
# 998  77e336c2-da69-460a-9b39-47a0fb27b536       Quanta Services, Inc.
# 999  4a51c7f5-ab10-4ec0-9a17-f9872aadb283               Ubiquiti Inc.
#
#     headquarters     country continent region sub_region           founded  \
# ...

# %%
df_Disfold_FR = pd.read_json('./Datasets for RL/Disfold/disfold_fr_m.json')
df_Disfold_FR
# Out:
#                                        id                            name  \
# 0    eef9ebb2-3251-4ca5-818e-013c89247e80                           Apple
# 1    bf819b7e-c4b2-40e9-879a-0a0553328d49                       Microsoft
# 2    ae5a1781-0fec-4cce-8e0f-1838993018a8                          Aramco
# 3    0a6a6fe4-1bbe-4b8d-82f5-01f9fd35da50                        Alphabet
# 4    fc684188-98dd-4a26-9cca-bca7dca904ba                          Amazon
# ..                                    ...                             ...
# 894  dbf25cb3-32a6-4026-9f24-44ad89c6d0d4              Markel Corporation
# 895  5ef5b739-b301-4430-8763-9156e6d728f4             Brown & Brown, Inc.
# 896  70cd2e93-0c63-4500-a0a4-e22e8bb8b2b8   Nomura Research Institute Ltd
# 897  72a99a25-89a5-44d0-8879-09f593eab6bb       MGM Resorts International
# 898  513a6867-6295-470c-9bdd-3df73cafdd5f  Mega Financial Holding Co. Ltd
#
#     headquarters country continent region sub_region  \
# 0
# 1
# 2
# 3
# 4
# ...

# %%
indexer = recordlinkage.Index()
indexer.full()
pairs = indexer.index(df_Disfold_Avengers, df_Disfold_FR)
# Out:
# WARNING:recordlinkage:indexing - performance warning - A full index can result in large number of record pairs.

# %%
print (len(df_Disfold_Avengers), len(df_Disfold_FR), len(pairs))
# Out:
# 1000 899 899000

# %%
indexer = recordlinkage.Index()
indexer.block("name")
candidate_links = indexer.index(df_Disfold_Avengers, df_Disfold_FR)
len(candidate_links)
candidate_links
# Out:
# MultiIndex([(  0,   0),
#             (  1,  49),
#             (  2,  48),
#             (  4,  46),
#             (  5,  45),
#             (  6,  44),
#             (  7,  43),
#             (  8,  42),
#             ( 10,  40),
#             ( 11,  39),
#             ...
#             (879, 869),
#             (882, 866),
#             (883, 865),
#             (885, 863),
#             (888, 860),
#             (889, 859),
#             (891, 857),
#             (894, 854),
#             (896, 852),
#             (897, 851)],
#            length=503)
