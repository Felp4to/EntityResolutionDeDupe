# %%
import pandas as pd

# %%
df_Disfold_FR = pd.read_json('./Record Linkage/Datasets for RL/Disfold/disfold_fr_m.json')

# %%
df_Disfold_FR
# Out:
#                                        id                            name  \
# 0    2a50924e-8fea-44ac-9108-d11b5c84db4a                           Apple
# 1    118bc8de-0b90-43fc-b7a4-32835c17448d                          Apple.
# 2    118bc8de-0b90-43fc-b7a4-32835c17448d                       Microsoft
# 3    bbc75ca1-e3e4-4d48-858c-59d5cfc0cb80                          Aramco
# 4    ae47ac0c-74a6-4fde-ae09-53f8f9063dd2                        Alphabet
# ..                                    ...                             ...
# 895  7cbae98d-b2a0-4c6c-b76b-f6b2f58e950a              Markel Corporation
# 896  ee882ec3-4e43-474c-92a1-4e371c8caf18             Brown & Brown, Inc.
# 897  d2e2cb2d-2bcf-4e74-9e13-69b00f04e17f   Nomura Research Institute Ltd
# 898  039075cb-7d86-49f5-8304-0db8a85c5c83       MGM Resorts International
# 899  bfb1d81f-2fba-444f-a0e1-69a0390df043  Mega Financial Holding Co. Ltd
#
#     headquarters country continent region sub_region  \
# 0
# 1
# 2
# 3
# 4
# ...

# %%
print(df_Disfold_FR.loc[1])
# Out:
# id                   118bc8de-0b90-43fc-b7a4-32835c17448d
# name                                               Apple.
# headquarters
# country
# continent
# region
# sub_region
# founded                            Founded: April 4, 1975
# employees                              Employees: 181,000
# ceo                                CEO: Mr. Satya Nadella
# market_cap
# categories
# sector
# industry
# code
# rank
# revenue
# net_income
# link
# share_price
# change_1_day
# change_1_year
# results_for_year
# total_assets
# total_liabilities
# total_equity
# founders
# market_value
# address
# type
# Name: 1, dtype: object
